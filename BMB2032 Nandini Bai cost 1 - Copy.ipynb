# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1439783511.py in <cell line: 0>()
# ----> 1 eq
#
# NameError: name 'eq' is not defined

# %%
Equipment=["tractor","plough","harvester","seeder","sprayer"]
cost=[850000,25000,1200000,60000,18000,95000]
#increase cost by 8%
updated_cost=[]
for y in cost :
    updated_cost.append(y*1.08)
print("actual costs:",cost)
print("updated costs:",updated_cost)
# Out:
# actual costs: [850000, 25000, 1200000, 60000, 18000, 95000]
# updated costs: [918000.0000000001, 27000.0, 1296000.0, 64800.00000000001, 19440.0, 102600.0]

# %%
Equipment=["tractor","plough","harvester","seeder","sprayer"]
cost=[850000,25000,1200000,60000,18000,95000]
updated_cost=[int(c*1.08) for c in cost]
print("updated costs:",updated_cost)
# Out:
# updated costs: [918000, 27000, 1296000, 64800, 19440, 102600]

# %%
equipment=["tractor","plough","harvester","seeder","sprayer"]
cost=[850000,25000,1200000,60000,18000,95000]
#replace equipment with cost above rs 1000000 as "high investors"
equipment_updated=[]
for i in range (len(equipment)):
  if updated_cost[i]>100000:
    equipment_updated.append("high investment")
else:
     equipment_updated.append(equipment[i])
     print("equipment updated with high investment replacement:\n",equipment_updated)
# Out:
# equipment updated with high investment replacement:
#  ['high investment', 'high investment', 'sprayer']

# %%
equipment_updated1=[]
"high investment "if c>1000000 else e for e,c in zip (equipment_updated,cost)
print("equipment list after replacement :\n",equipment_updated)
# Out:
#   File "/tmp/ipython-input-259324598.py", line 2
#     "high investment "if c>1000000 else e for e,c in zip (equipment_updated,cost)
#                                           ^
# SyntaxError: invalid syntax

# %%
categories=[]
for c in updated_cost:
  if c<100000:
    categories.append("low")
  elif c<=500000:
    categories.append("medium")
  else:
   categories.append("high")
print("cost categories:",categories)
# Out:
# cost categories: ['high', 'low', 'high', 'low', 'low', 'medium']

# %%
categories=[]
for c in updated_cost:
  if c<1000000:
    categories.append("low")
  elif c<=500000:
    categories.append("medium")
  else:
    categories.append("high")
    print("cost categories:",categories)
# Out:
# cost categories: ['low', 'low', 'high']

# %%
# Reduce the cost of the equipment by 15% for subsidy eligible equipment
#Assume subsidy for equipment costing below Rs100000
subsidy_cost=[]
for c in cost :
  if c<100000:
    subsidy_cost.append(int(c*0.85))
  else:
    subsidy_cost.append(c)
    print("costs after subsidy:",subsidy_cost)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2248461169.py in <cell line: 0>()
#       7   else:
#       8     subsidy_cost.append(c)
# ----> 9     print("costs after subsidy:",subsidy_cost)
#
# TypeError: 'tuple' object is not callable

# %%
equipment=["tractor","plough","harvester","seeder","sprayer"]
cost=[850000,25000,1200000,60000,18000,95000]
subsidy_cost=[int(c*0.85) for c in cost]
print("subsidy_cost",subsidy_cost)
# Out:
# subsidy_cost [722500, 21250, 1020000, 51000, 15300, 80750]

# %%
equipment=["tractor","plough","harvester","seeder","sprayer"]
cost=[850000,25000,1200000,60000,18000,95000]
subsidy_cost=[float(c*0.85)if c<100000 else c for c in cost]
print(subsidy_cost)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2876827369.py in <cell line: 0>()
#       2 cost=[850000,25000,1200000,60000,18000,95000]
#       3 subsidy_cost=[float(c*0.85)if c<100000 else c for c in cost]
# ----> 4 print(subsidy_cost)
#
# TypeError: 'tuple' object is not callable

# %%
equipment=["tractor","plough","harvester","seeder","sprayer"]
cost=[850000,25000,1200000,60000,18000,95000]
print("the least expensive equipment:",)
n=min(cost)
i=cost.index(n)
print(equipment[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-751364726.py in <cell line: 0>()
#       1 equipment=["tractor","plough","harvester","seeder","sprayer"]
#       2 cost=[850000,25000,1200000,60000,18000,95000]
# ----> 3 print("the least expensive equipment:",)
#       4 n=min(cost)
#       5 i=cost.index(n)
#
# TypeError: 'tuple' object is not callable

# %%
equipment=["tractor","plough","harvester","seeder","sprayer"]
cost=[850000,25000,1200000,60000,18000,95000]
avg=sum(cost)/len(cost)
print=("avg cost",avg)

# %%
p="hi"
print(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-164350068.py in <cell line: 0>()
#       1 p="hi"
# ----> 2 print(p)
#
# TypeError: 'tuple' object is not callable
