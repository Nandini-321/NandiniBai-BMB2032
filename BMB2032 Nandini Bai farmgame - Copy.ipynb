# %%
#Choose the option
1.plants to seed🌱🌱
2.water crops💧🫗🫗
3.Harvest crop🌾🌽
4.Exit

while true:
  print("Welcome to farm game")
  crops=0
  while True:
    print("1.plant to seed")
    print("2.water crops")
    print("3.harvest crops")
    print("4.exit")
  choice=(input("enter the choice"))

if choice=='1':
  crops+=1
  print("plant to seed")
elif choice=='2':
  if crops>=1
# Out:
# Welcome to farm game
# 1.plant to seed
# 2.water crops
# 3.harvest crops
# 4.exit
# plant to seed
# 1.plant to seed
# 2.water crops
# 3.harvest crops
# 4.exit
# harvest crops
# 1.plant to seed
# 2.water crops
# 3.harvest crops
# 4.exit

# %%
import random

fish_dict={
    "Rahu":12,
    "Catla":18,
    "Sinchu":25
}
random_fish=random.choice(list(fish_dict.keys()))
print(random_fish)
# Out:
# Catla

# %%
import random
random.randint(1,10)
# Out:
# 4

# %%
import random
number=[1,2,3,4,5]
print(random.sample(number,3))
# Out:
# [3, 1, 2]

# %%
money=50
print("I have $",money)
# Out:
# I have $ 50
