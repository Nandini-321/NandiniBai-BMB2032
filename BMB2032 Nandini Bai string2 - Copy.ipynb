# %%
crop_name="Groundnut"
print(crop_name[0])
print(crop_name[-1])
print(crop_name[:5])
print(crop_name[5:])
# Out:
# G
# t
# Groun
# dnut

# %%
print("rice".upper())
print("wheat".lower())
print("green gram".title())
print("cotton crop".capitalize())
# Out:
# RICE
# wheat
# Green Gram
# Cotton crop

# %%
raw_crop="Rice"
print(raw_crop.strip())
print("***Wheat".lstrip("*"))
print("Maize###".rstrip("#"))
# Out:
# Rice
# Wheat
# Maize

# %%
text="Organic Rice and Rice cultivation"
print(text.find("Rice"))
print(text.count("Rice"))
# Out:
# 8
# 2

# %%
print("Rice".isalpha())
print("2026".isdigit())
print("Plot12".isalnum())
print(" ".isspace())
# Out:
# True
# True
# True
# True

# %%
crop_info="Rice crop"
updated_crop_info=crop_info.replace("Rice","Wheat")
print(updated_crop_info)
# Out:
# Wheat crop

# %%
record="Rice,1200,Black Soil"
field=record.split(",")
print(field)
# Out:
# ['Rice', '1200', 'Black Soil']

# %%
joined_record=",".join(field)
print(joined_record)
# Out:
# Rice,1200,Black Soil

# %%
crop="Rice"
yeild_kg=1200
print(f"Crop:{crop},Yeild:{yeild_kg}kg")
print("crop:{},Yeild:{}kg".format(crop,yeild_kg))
# Out:
# Crop:Rice,Yeild:1200kg
# crop:Rice,Yeild:1200kg

# %%
print("farmer's crop record")
print("Line1\nLine2")
print(sorted("wheat"))
# Out:
# farmer's crop record
# Line1
# Line2
# ['a', 'e', 'h', 't', 'w']

# %%
crop_code="CRP_RICE_2026"
print(crop_code.startswith("CRP"))
print(crop_code.endswith("2025"))
# Out:
# True
# False

# %%
codes=[
    "CRP_RICE_2026",
    "CPR_WHEAT_2025",
    "FRT_MANGO_2026,"
    "CRP_MAIZE_2024",

]
filtered=[]
for crop_code in codes:
  if crop_code.startswith("CRP_"):#True
    filtered.append(crop_code)
print(filtered)
# Out:
# ['CRP_RICE_2026']

# %%
codes=[
    "CRP_RICE_2026",
    "CPR_WHEAT_2025",
    "FRT_MANGO_2026,"
    "CRP_MAIZE_2024",

]
clean_codes=[]

for code in codes:

  if code.startswith("CRP_"):
    clean_codes.append(code[4:])


print(clean_codes)
# Out:
# ['RICE_2026']

# %%
codes=[
    "CRP_RICE_2026",
    "CPR_WHEAT_2025",
    "FRT_MANGO_2026,"
    "CRP_MAIZE_2024",

]

for crop_code in codes:
  if crop_code.startswith("CRP_"):
    code,crop,year=crop_code.split("_")
    print(crop,year)
# Out:
# RICE 2026

# %%
raw_record=" Rice,1200,Black Soil**"
clean_record=raw_record.strip()
clean_record1=clean_record.split("*")
crop,yeild_kg,soil=clean_record1[0].split(",")
crop=crop.title()

print(f"Crop:{crop}")
print(f"yeild:{yeild_kg}kg")
print(f"soil:{soil}")
# Out:
# Crop:Rice
# yeild:1200kg
# soil:Black Soil

# %%
a="Today is 20-01-2026 Tuesday"
d=b=v=c=o=0
for i in a:
  if i.isspace():
    b=b+1
  elif i in "aeiou":
      v=v+1
  elif i.isalpha():
      c=c+1
  elif i.isdigit():
        d=d+1
  else:
        o=o+1
print("The number of blank spaces are",b)
print("The number of vowels  are",v)
print("The number of conconents are",c)
print("The number of digits are",d)
print("The number of other characters are",o)
# Out:
# The number of blank spaces are 3
# The number of vowels  are 6
# The number of conconents are 8
# The number of digits are 8
# The number of other characters are 2
