# %%
#requered argument
def printme(str):
  print(str)
  return

printme("hello")
printme("122")
# Out:
# hello
# 122

# %%
def printme(str):
  print(str)
  return

printme("hello")
printme("122")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1716363973.py in <cell line: 0>()
#       3   return
#       4
# ----> 5 printme("hello","hii")
#       6 printme("122")
#
# TypeError: printme() takes 1 positional argument but 2 were given

# %%
#keyword argument
def printme(str):
  print(str)
  return

printme("hello")
printme(str="my girl")
# Out:
# hello
# my girl

# %%
def printme(str):
  print(str)
  return

printme("hello")
printme(str="my girl")
printme(abc="my girl")
# Out:
# hello
# my girl
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2241529223.py in <cell line: 0>()
#       5 printme("hello")
#       6 printme(str="my girl")
# ----> 7 printme(abc="my girl")
#
# TypeError: printme() got an unexpected keyword argument 'abc'

# %%
#default argument
def fun(a,b=5,c=10):
  print("a is:",a,"b is:",b,"c is :",c)
fun(3,7)
fun(25,c=34)
fun(c=50,a=100)
# Out:
# a is: 3 b is: 7 c is : 10
# a is: 25 b is: 5 c is : 34
# a is: 100 b is: 5 c is : 50

# %%
def check(Name,*marks):
  print(Name)
  print(marks)
check("XYZ",10,20,30)
# Out:
# XYZ
# (10, 20, 30)

# %%
def check(name,*marks):
  print(name)
  print(marks)
check(marks='xyz',10,20,30)
# Out:
#   File "/tmp/ipython-input-3857821320.py", line 4
#     check(marks='xyz',10,20,30)
#                               ^
# SyntaxError: positional argument follows keyword argument
