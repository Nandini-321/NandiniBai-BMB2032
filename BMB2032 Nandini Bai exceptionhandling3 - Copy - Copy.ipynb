# %%
try:
  file=open("xyz.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("file not found")
# Out:
# file not found

# %%
try:
  with open('abc.txt','r')as f:
    line=f.read()
    print(line)
except:
    print("error!! no such file")
# Out:
# error!! no such file

# %%
try:
  a=10
  b=20
  c=a+d
  print(c)
except:
  print("some issue!!")
# Out:
# some issue!!

# %%
def expr(a,b):
  c=a/b
  print(c)
a=20
b=10
expr(a,b)
# Out:
# 2.0

# %%
def expr(a,b):
  c=a/b
  print(c)
a=20
b=0
expr(a,b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-3395411625.py in <cell line: 0>()
#       4 a=20
#       5 b=0
# ----> 6 expr(a,b)
#
# /tmp/ipython-input-3395411625.py in expr(a, b)
#       1 def expr(a,b):
# ----> 2   c=a/b
#       3   print(c)
#       4 a=20
#       5 b=0
#
# ZeroDivisionError: division by zero

# %%
def expr(a,b):
  c=a/d
  print(c)
a=20
b=10
expr(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3006195662.py in <cell line: 0>()
#       4 a=20
#       5 b=10
# ----> 6 expr(a,b)
#
# /tmp/ipython-input-3006195662.py in expr(a, b)
#       1 def expr(a,b):
# ----> 2   c=a/d
#       3   print(c)
#       4 a=20
#       5 b=10
#
# NameError: name 'd' is not defined

# %%
try:
def expr(a,b):
  c=a/b
  print(c)
 a=20
b=10
expr(a,b)
except:
  print("some issue!!")
# Out:
#   File "/tmp/ipython-input-2950571955.py", line 2
#     def expr(a,b):
#     ^
# IndentationError: expected an indented block after 'try' statement on line 1

# %%
def expr(a,b):
  try:
      c=a/f
  except ZeroDivisionError:
      print("divided by 0")
  except NameError:
      print("variable not defined")
  except:
      print("some issue!!")
  else:
    print("executed without error")
    print("value of c",c)

  finally:
    print("end of the program")
  a=float(input("enter no. a"))
  b=float(input("enter no. b"))
  expr(a,b)
