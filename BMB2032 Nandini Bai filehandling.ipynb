# %%
#without saving
file=open("abc.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2749428419.py in <cell line: 0>()
# ----> 1 file=open("abc.txt","r")
#       2 content=file.read()
#       3 print(content)
#       4 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
#write
file=open("GKVK.txt","w")
file.write("hello pallavi")
file.close()

# %%
file=open("GKVK.txt","w")
file.write("how are you pallavi")
file.close()

# %%
file=open("GKVK.txt","a")
file.write("\nthis is appended txt")
file.close()

# %%
#read
file=open("GKVK.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# how are you pallavi
# this is appended txt

# %%
#readline
file=open("GKVK.txt","r")
content=file.readline()
print(content)
file.close()
# Out:
# how are you pallavi

# %%
#readlines
file=open("GKVK.txt","r")
content=file.readlines()
print(content)
file.close()
# Out:
# ['how are you pallavi\n', 'this is appended txt']

# %%
#another method read
with open("GKVK.txt","r")as file:
  print(file.read())
# Out:
# how are you pallavi
# this is appended txt
