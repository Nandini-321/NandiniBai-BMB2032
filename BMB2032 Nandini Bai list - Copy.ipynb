# %%
lst=[1,2,3]
for x in list:
  lst.append(x)
  if len(lst)>4:
    break
print(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1088318531.py in <cell line: 0>()
#       1 lst=[1,2,3]
# ----> 2 for x in list:
#       3   lst.append(x)
#       4   if len(lst)>4:
#       5     break
#
# TypeError: 'type' object is not iterable

# %%
x=5
if x>0:
  if x>10:
    print("large positive")
  else:
    print("small positive")
else:
    print("non positive")
# Out:
# small positive

# %%
nums=[1,2,3,4,5]
for n in nums:
  if n<=3:
    print(n)
# Out:
# 1
# 2
# 3

# %%
for i in range (len(nums)):
  if nums[i]>3:
    print(nums[i])
# Out:
# 4
# 5

# %%
x=int(input())
if x>0:
  print("positive")
elif x==0:
  print("zero")
else:
      print("negative")
