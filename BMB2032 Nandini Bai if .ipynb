# %%
if 10>5:
   print("10 is greater than 5")
# Out:
# 10 is greater than 5

# %%
if 20>10:
  print("20 is greater than 10")
# Out:
# 20 is greater than 10

# %%
a=20
b=10
if a>b:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
c=30
d=20
if c>d:
  print(c*d)
# Out:
# 600

# %%
a=20
b=30
if a>b:
  print ("a is greater than b")
else:
     print("b is grater than a")
# Out:
# b is grater than a

# %%
a=32
b=49
if a+b>70:
  print ("nandini")
else:
    print("nanditha")
# Out:
# nandini

# %%
a=17
b=20
if(a&b>18):
    print(" eligible for vote")
    print ("he can vote")
else:
    print("you are minor")
    print("ill vote next year")
# Out:
# you are minor
# ill vote next year

# %%
a=20
if("a>18"):
  print("nanditha is eligible for vote")
else:
  print("nanditha is not eligible for voting")
# Out:
# nanditha is eligible for vote

# %%
a=7
if (a>=8):
  print("a is positive")
elif(a<0):
    print("a is negitive")
else:
    print("a is neutra")
# Out:
# a is neutra

# %%
g=8
if(g>9):
    print("A")
elif(g>=7 and <9):
    print("B")
elif(g>=5 and <7):
    print("C")
else:
    print("fail")
# Out:
#   File "/tmp/ipython-input-3079519882.py", line 4
#     elif(g>=7 and <9):
#                   ^
# SyntaxError: invalid syntax

# %%
m=1
if(m>=9):
    print("A grade")
elif(m>=7 and m<9):
    print("B grade")
elif(m>=5 and m<7):
    print("C grade")
else:
   print("fail")
# Out:
# fail

# %%
a=973134509789
if(a%2==0):
  print("even")
else:
    print("odd")
# Out:
# odd
